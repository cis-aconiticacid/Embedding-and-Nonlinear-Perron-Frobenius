# %%
import json
import os
from pathlib import Path
import sys
import numpy as np
import matplotlib.pyplot as plt
import torch

_old_sys_path = sys.path.copy()
try:
    project_root = Path.cwd().parent
    sys.path.insert(0, str(Path.cwd().resolve().parents[1]))
    from functions import graph_print_analysis as gp_tool
    from train_mnist_with_network import HBModel_MNIST as hbm
    from functions import dataload 
finally:
    sys.path = _old_sys_path
# Out:
# Project root added to sys.path: c:\Users\ASUS\Desktop\cone_dynamics

# %%
root_path=Path.cwd().parent.parent
experimental_path=root_path / "experiments"

# %%
file_path=experimental_path/"MNIST_network"/"mnist_hilbert_bs256_lr0.01_decayTrue_regTrue_steps500_traj.pt"
state_dict = torch.load(file_path, map_location='cpu',weights_only=True)
param_traj=state_dict

# %%
w_final=param_traj[-1]
res=gp_tool.analysis_to_w_star(param_traj,False,False,if_show=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 w_final=param_traj[-1]
# ----> 2 res=gp_tool.analysis_to_w_between(param_traj,False,False,if_show=True)
#
# File ~\Desktop\cone_dynamics\functions\graph_print_analysis.py:311, in analysis_to_w_between(trajectory, if_writes, if_print, plt_title, save_name, saved_path, if_show, threshold, if_masked, if_self_adaptive, if_smooth)
#     308 results["hilbert_between"] = unmasked_between
#     310 if if_show:
# --> 311     plot_hb(
#     312         unmasked_between,
#     313         saved_name=f"{save_name}_between.png",
#     314         saved_path=save_dir ,
#     315         plt_title=f"{plt_title} (Unmasked)",
#     316         if_show=if_show,
#     317         if_smooth=if_smooth,
#     318     )
#     320 if if_writes:
#     321     results["unmasked_stats"] = write_stats(
#     322         unmasked_between,
#     323         saved_name=f"{save_name}_between_stats.txt",
#     324         saved_path=save_dir,if_print=if_print,
#     325     )
#
# File ~\Desktop\cone_dynamics\functions\graph_print_analysis.py:110, in plot_hb(values, if_smooth, smooth_window, max_points, plt_title, saved_name, saved_path, if_show)
#     107 plt.axhline(1.0, linestyle="--", linewidth=1)
#     108 plt.tight_layout()
# --> 110 save_dir = Path(saved_path)
#     111 if saved_path is not None:
#     112     save_dir.mkdir(parents=True, exist_ok=True)
#
# File c:\Users\ASUS\anaconda3\envs\py311\Lib\pathlib.py:871, in Path.__new__(cls, *args, **kwargs)
#     869 if cls is Path:
#     870     cls = WindowsPath if os.name == 'nt' else PosixPath
# --> 871 self = cls._from_parts(args)
#     872 if not self._flavour.is_supported:
#     873     raise NotImplementedError("cannot instantiate %r on your system"
#     874                               % (cls.__name__,))
#
# File c:\Users\ASUS\anaconda3\envs\py311\Lib\pathlib.py:509, in PurePath._from_parts(cls, args)
#     504 @classmethod
#     505 def _from_parts(cls, args):
#     506     # We need to call _parse_args on the instance, so as to get the
#     507     # right flavour.
#     508     self = object.__new__(cls)
# --> 509     drv, root, parts = self._parse_args(args)
#     510     self._drv = drv
#     511     self._root = root
#
# File c:\Users\ASUS\anaconda3\envs\py311\Lib\pathlib.py:493, in PurePath._parse_args(cls, args)
#     491     parts += a._parts
#     492 else:
# --> 493     a = os.fspath(a)
#     494     if isinstance(a, str):
#     495         # Force-cast str subclasses to str (issue #21127)
#     496         parts.append(str(a))
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType
