# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader


# ============================================
# 1. Swiss roll 数据生成 + 高维嵌入
# ============================================

def generate_swiss_roll(n_samples, D=32, noise=0.0, device="cpu"):
    """
    生成 Swiss roll:
      - 参数 (u, v)
      - 3D: (x1, x2, x3)
      - 高维嵌入: A @ x_3d, A ∈ R^{D x 3} 正交列

    返回:
      X_high: (n_samples, D)
      y:      (n_samples,)  -- 一个光滑的 target（这里用 sin(u) 做 toy）
      u, v:   (n_samples,)  -- 方便你以后做 intrinsic 对比
    """
    u = torch.empty(n_samples, device=device).uniform_(3 * math.pi, 9 * math.pi)
    v = torch.empty(n_samples, device=device).uniform_(0.0, 20.0)

    x1 = u * torch.cos(u)
    x2 = v
    x3 = u * torch.sin(u)

    X3 = torch.stack([x1, x2, x3], dim=1)  # (n, 3)

    if noise > 0:
        X3 = X3 + noise * torch.randn_like(X3)

    # 随机高维正交嵌入
    # A: (D, 3), 列正交
    A = torch.randn(D, 3, device=device)
    # QR 分解，取 Q 的前 3 列
    Q, _ = torch.linalg.qr(A, mode="reduced")  # Q: (D, 3)
    X_high = X3 @ Q.T  # (n, 3) @ (3, D) -> (n, D)

    # toy 的回归目标：y = sin(u) / u 之类的平滑函数
    y = torch.sin(u) / (u + 1.0)

    return X_high, y, u, v


# ============================================
# 2. Hilbert 射影度量（正锥 R^m_{>0}）
# ============================================

def hilbert_distance(x, y, eps=1e-8):
    """
    x, y: (m,) 正向量（>0）
    d_H(x, y) = log( max_i x_i / y_i ) - log( min_i x_i / y_i )

    返回: float
    """
    # 避免 0
    x_safe = x.clamp_min(eps)
    y_safe = y.clamp_min(eps)
    ratio = x_safe / y_safe
    max_r = ratio.max()
    min_r = ratio.min()
    return (max_r.log() - min_r.log()).item()


# ============================================
# 3. 简单正锥模型：正权重线性回归
#    w = softplus(theta) ∈ R^D_{>0}
# ============================================

class PositiveLinear(nn.Module):
    """
    y_hat = X @ w, 其中 w = softplus(theta) > 0
    这样参数 w 始终在正锥内部，可以监控 Hilbert metric。
    """

    def __init__(self, D):
        super().__init__()
        # 可训练参数 theta ∈ R^D
        self.theta = nn.Parameter(torch.zeros(D))

    def forward(self, X):
        # softplus 保证正性
        w = F.softplus(self.theta)
        return X @ w

    def positive_params_vector(self):
        # 把当前的 “正锥参数” 摊平成一个向量，用于算 Hilbert 距离
        w = F.softplus(self.theta)
        return w.detach().clone()

# %%
def run_experiment_on_subset(
    X_full, y_full, n,
    num_epochs=500,
    lr=1e-2,
    l2_reg=1e-3,
    huber = torch.nn.SmoothL1Loss(beta=1.0),
    device="cuda"
):
    N, D = X_full.shape
    idx = torch.randperm(N, device=device)[:n]
    X = X_full[idx]
    y = y_full[idx]

    dataset = TensorDataset(X, y)
    loader = DataLoader(dataset, batch_size=n, shuffle=False)  # full-batch

    model = PositiveLinear(D).to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=lr)

    param_traj = []
    loss_traj = []

    for epoch in range(num_epochs):
        for batch_X, batch_y in loader:
            optimizer.zero_grad()

            # 1. 预测
            y_pred = model(batch_X)

            # 2. Huber loss 部分
            huber = torch.nn.SmoothL1Loss(beta=1.0)
            huber_loss = huber(y_pred, batch_y)

            # 3. L2 正则：在正锥中对 w = softplus(theta) 做正则
            w = F.softplus(model.theta)
            l2 = (w ** 2).sum()

            # 4. 总 loss = huber_loss + λ ||w||^2
            loss = huber_loss + l2_reg * l2

            loss.backward()
            optimizer.step()

        loss_traj.append(loss.item())
        param_traj.append(model.positive_params_vector().cpu())

    w_star = param_traj[-1]
    w_init = param_traj[0]

    hilbert_to_final = []
    hilbert_to_init = []
    hilbert_between = []

    prev = param_traj[0]
    for w_t in param_traj:
        hilbert_to_final.append(hilbert_distance(w_t, w_star))
        hilbert_to_init.append(hilbert_distance(w_t, w_init))
        hilbert_between.append(hilbert_distance(w_t, prev))
        prev = w_t

    return {
        "n": n,
        "loss_traj": loss_traj,
        "hilbert_to_final": hilbert_to_final,
        "hilbert_to_init": hilbert_to_init,
        "hilbert_between": hilbert_between,
        "w_star": w_star,
    }

# %%
def main():
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print("Using device:", device)

    # ----- 生成大样本 Swiss roll -----
    N = 10_000
    D = 32
    X_full, y_full, u, v = generate_swiss_roll(
        n_samples=N,
        D=D,
        noise=0.0,
        device=device,
    )
    print(f"Full dataset: X={X_full.shape}, y={y_full.shape}")

    # ----- 不同小样本规模 -----
    n_list = [50, 100, 200, 500]
    num_epochs = 500
    lr = 1e-2
    l2_list = [0.0, 1e-4, 1e-3, 1e-2]

    # all_results[n][l2_reg] = 对应的实验结果
    all_results = {}

    for n in n_list:
        all_results[n] = {}
        print(f"\n================ n = {n} ================")

        for l2_reg in l2_list:
            print(f"\n--- Running experiment (n={n}, l2_reg={l2_reg}) ---")
            res = run_experiment_on_subset(
                X_full,
                y_full,
                n=n,
                num_epochs=num_epochs,
                lr=lr,
                l2_reg=l2_reg,
                device=device,
            )
            all_results[n][l2_reg] = res

            print(f"Final loss: {res['loss_traj'][-1]:.6f}")
            print(f"Initial d_H(w_t, w*): {res['hilbert_to_final'][0]:.6f}")
            print(f"Final   d_H(w_t, w*): {res['hilbert_to_final'][-1]:.6f}")

            print("First 5 d_H(w_t, w*):", res["hilbert_to_final"][:5])
            print("First 5 d_H(w_t, w_0):", res["hilbert_to_init"][:5])
            print("First 5 d_H(w_{t+1}, w_t):", res["hilbert_between"][:5])

    # 例如保存结果
    torch.save(all_results, "swiss_roll_cone_huber_loss.pt")

# %%
main()  # --- IGNORE ---
# Out:
# Using device: cuda
# Full dataset: X=torch.Size([10000, 32]), y=torch.Size([10000])
#
# ================ n = 50 ================
#
# --- Running experiment (n=50, l2_reg=0.0) ---
# Final loss: 0.000180
# Initial d_H(w_t, w*): 1.890641
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [1.8906409740447998, 1.8552935123443604, 1.8200749158859253, 1.7849822044372559, 1.7500104904174805]
# First 5 d_H(w_t, w_0): [0.0, 0.03534744679927826, 0.07056592404842377, 0.10565873980522156, 0.14063040912151337]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.03534744679927826, 0.03521854430437088, 0.03509276360273361, 0.034971632063388824]
#
# --- Running experiment (n=50, l2_reg=0.0001) ---
# Final loss: 0.001793
# Initial d_H(w_t, w*): 1.892352
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [1.892351508140564, 1.8581247329711914, 1.8240289688110352, 1.790064811706543, 1.7562315464019775]
# First 5 d_H(w_t, w_0): [0.0, 0.03486048802733421, 0.06959608197212219, 0.1042020246386528, 0.1386747658252716]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.03486048802733421, 0.03473557531833649, 0.03460600972175598, 0.0344727449119091]
#
# --- Running experiment (n=50, l2_reg=0.001) ---
# Final loss: 0.016598
# Initial d_H(w_t, w*): 1.893343
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [1.8933426141738892, 1.8595917224884033, 1.8258848190307617, 1.792242407798767, 1.7586686611175537]
# First 5 d_H(w_t, w_0): [0.0, 0.036923326551914215, 0.0736560970544815, 0.11021155118942261, 0.1465792953968048]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.036923326551914215, 0.03673280030488968, 0.03655547648668289, 0.036367740482091904]
#
# --- Running experiment (n=50, l2_reg=0.01) ---
# Final loss: 0.157050
# Initial d_H(w_t, w*): 1.897914
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [1.897914171218872, 1.8686310052871704, 1.8394885063171387, 1.8104833364486694, 1.7816131114959717]
# First 5 d_H(w_t, w_0): [0.0, 0.03738774359226227, 0.0747114047408104, 0.11192042380571365, 0.14897000789642334]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.03738774359226227, 0.03732370585203171, 0.037209026515483856, 0.037049610167741776]
#
# ================ n = 100 ================
#
# --- Running experiment (n=100, l2_reg=0.0) ---
# Final loss: 0.000217
# Initial d_H(w_t, w*): 1.897949
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [1.8979490995407104, 1.8697298765182495, 1.8416038751602173, 1.8135716915130615, 1.7856336832046509]
# First 5 d_H(w_t, w_0): [0.0, 0.029360206797719002, 0.05863179638981819, 0.08781228959560394, 0.11689899861812592]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.029360206797719002, 0.0292716883122921, 0.02918056771159172, 0.029086675494909286]
#
# --- Running experiment (n=100, l2_reg=0.0001) ---
# Final loss: 0.001885
# Initial d_H(w_t, w*): 1.895525
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [1.8955254554748535, 1.8645517826080322, 1.8336809873580933, 1.8029152154922485, 1.7722562551498413]
# First 5 d_H(w_t, w_0): [0.0, 0.033273570239543915, 0.06644022464752197, 0.0994967520236969, 0.1324409544467926]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.033273570239543915, 0.033166591078042984, 0.03305651992559433, 0.032944198697805405]
#
# --- Running experiment (n=100, l2_reg=0.001) ---
# Final loss: 0.016649
# Initial d_H(w_t, w*): 1.893875
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [1.893875241279602, 1.8612620830535889, 1.8287441730499268, 1.796310544013977, 1.7639496326446533]
# First 5 d_H(w_t, w_0): [0.0, 0.036635518074035645, 0.0731436163187027, 0.109506756067276, 0.14570605754852295]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.036635518074035645, 0.03650815039873123, 0.03636312112212181, 0.036199282854795456]
#
# --- Running experiment (n=100, l2_reg=0.01) ---
# Final loss: 0.157039
# Initial d_H(w_t, w*): 1.894864
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [1.8948638439178467, 1.8623985052108765, 1.8300435543060303, 1.79780113697052, 1.765672206878662]
# First 5 d_H(w_t, w_0): [0.0, 0.036138035356998444, 0.07218384742736816, 0.10813387483358383, 0.14398536086082458]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.036138035356998444, 0.036045756191015244, 0.03595003858208656, 0.03585149347782135]
#
# ================ n = 200 ================
#
# --- Running experiment (n=200, l2_reg=0.0) ---
# Final loss: 0.000236
# Initial d_H(w_t, w*): 1.893227
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [1.8932273387908936, 1.859998345375061, 1.8268903493881226, 1.7939051389694214, 1.7610437870025635]
# First 5 d_H(w_t, w_0): [0.0, 0.03322876989841461, 0.06633682548999786, 0.09932206571102142, 0.13218334317207336]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.03322876989841461, 0.03310812637209892, 0.03298521786928177, 0.03286130353808403]
#
# --- Running experiment (n=200, l2_reg=0.0001) ---
# Final loss: 0.001855
# Initial d_H(w_t, w*): 1.893868
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [1.8938684463500977, 1.8615959882736206, 1.8294012546539307, 1.7972908020019531, 1.7652654647827148]
# First 5 d_H(w_t, w_0): [0.0, 0.03389212116599083, 0.06766512989997864, 0.10133522748947144, 0.13489916920661926]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.03389212116599083, 0.03377295285463333, 0.03367011249065399, 0.03356402367353439]
#
# --- Running experiment (n=200, l2_reg=0.001) ---
# Final loss: 0.016628
# Initial d_H(w_t, w*): 1.894760
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [1.8947595357894897, 1.8627768754959106, 1.830891728401184, 1.799102544784546, 1.7674038410186768]
# First 5 d_H(w_t, w_0): [0.0, 0.03547981381416321, 0.07084524631500244, 0.10608738660812378, 0.141188383102417]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.03547981381416321, 0.03536543250083923, 0.035242125391960144, 0.0351010225713253]
#
# --- Running experiment (n=200, l2_reg=0.01) ---
# Final loss: 0.157083
# Initial d_H(w_t, w*): 1.893806
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [1.893805980682373, 1.8601627349853516, 1.8266628980636597, 1.7933474779129028, 1.7602276802062988]
# First 5 d_H(w_t, w_0): [0.0, 0.03364328294992447, 0.06714310497045517, 0.10045871138572693, 0.13357827067375183]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.03364328294992447, 0.03349972143769264, 0.03331561014056206, 0.03311965614557266]
#
# ================ n = 500 ================
#
# --- Running experiment (n=500, l2_reg=0.0) ---
# Final loss: 0.000190
# Initial d_H(w_t, w*): 1.891225
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [1.8912246227264404, 1.8560411930084229, 1.821004867553711, 1.7861119508743286, 1.7513620853424072]
# First 5 d_H(w_t, w_0): [0.0, 0.035183340311050415, 0.0702197328209877, 0.1051127016544342, 0.13986244797706604]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.035183340311050415, 0.035036422312259674, 0.034892961382865906, 0.03474980592727661]
#
# --- Running experiment (n=500, l2_reg=0.0001) ---
# Final loss: 0.001870
# Initial d_H(w_t, w*): 1.893431
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [1.8934309482574463, 1.8604352474212646, 1.8275506496429443, 1.7947795391082764, 1.7621257305145264]
# First 5 d_H(w_t, w_0): [0.0, 0.03314388170838356, 0.06615843623876572, 0.09903890639543533, 0.13178278505802155]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.03314388170838356, 0.033014558255672455, 0.03288058191537857, 0.032743871212005615]
#
# --- Running experiment (n=500, l2_reg=0.001) ---
# Final loss: 0.016692
# Initial d_H(w_t, w*): 1.895897
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [1.8958966732025146, 1.8653771877288818, 1.8349628448486328, 1.8046538829803467, 1.7744513750076294]
# First 5 d_H(w_t, w_0): [0.0, 0.03078974038362503, 0.061477210372686386, 0.09205950796604156, 0.1225329115986824]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.03078974038362503, 0.03068743273615837, 0.03058229200541973, 0.03047332912683487]
#
# --- Running experiment (n=500, l2_reg=0.01) ---
# Final loss: 0.157065
# Initial d_H(w_t, w*): 1.894491
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [1.8944905996322632, 1.8613325357437134, 1.8283015489578247, 1.7953988313674927, 1.7626245021820068]
# First 5 d_H(w_t, w_0): [0.0, 0.03345978632569313, 0.06679380685091019, 0.0999961793422699, 0.13306155800819397]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.03345978632569313, 0.03333405777812004, 0.03320233151316643, 0.033065393567085266]
