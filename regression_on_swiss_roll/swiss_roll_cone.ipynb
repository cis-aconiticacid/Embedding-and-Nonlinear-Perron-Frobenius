# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader


# ============================================
# 1. Swiss roll 数据生成 + 高维嵌入
# ============================================

def generate_swiss_roll(n_samples, D=32, noise=0.0, device="cpu"):
    """
    生成 Swiss roll:
      - 参数 (u, v)
      - 3D: (x1, x2, x3)
      - 高维嵌入: A @ x_3d, A ∈ R^{D x 3} 正交列

    返回:
      X_high: (n_samples, D)
      y:      (n_samples,)  -- 一个光滑的 target（这里用 sin(u) 做 toy）
      u, v:   (n_samples,)  -- 方便你以后做 intrinsic 对比
    """
    u = torch.empty(n_samples, device=device).uniform_(3 * math.pi, 9 * math.pi)
    v = torch.empty(n_samples, device=device).uniform_(0.0, 20.0)

    x1 = u * torch.cos(u)
    x2 = v
    x3 = u * torch.sin(u)

    X3 = torch.stack([x1, x2, x3], dim=1)  # (n, 3)

    if noise > 0:
        X3 = X3 + noise * torch.randn_like(X3)

    # 随机高维正交嵌入
    # A: (D, 3), 列正交
    A = torch.randn(D, 3, device=device)
    # QR 分解，取 Q 的前 3 列
    Q, _ = torch.linalg.qr(A, mode="reduced")  # Q: (D, 3)
    X_high = X3 @ Q.T  # (n, 3) @ (3, D) -> (n, D)

    # toy 的回归目标：y = sin(u) / u 之类的平滑函数
    y = torch.sin(u) / (u + 1.0)

    return X_high, y, u, v


# ============================================
# 2. Hilbert 射影度量（正锥 R^m_{>0}）
# ============================================

def hilbert_distance(x, y, eps=1e-8):
    """
    x, y: (m,) 正向量（>0）
    d_H(x, y) = log( max_i x_i / y_i ) - log( min_i x_i / y_i )

    返回: float
    """
    # 避免 0
    x_safe = x.clamp_min(eps)
    y_safe = y.clamp_min(eps)
    ratio = x_safe / y_safe
    max_r = ratio.max()
    min_r = ratio.min()
    return (max_r.log() - min_r.log()).item()


# ============================================
# 3. 简单正锥模型：正权重线性回归
#    w = softplus(theta) ∈ R^D_{>0}
# ============================================

class PositiveLinear(nn.Module):
    """
    y_hat = X @ w, 其中 w = softplus(theta) > 0
    这样参数 w 始终在正锥内部，可以监控 Hilbert metric。
    """

    def __init__(self, D):
        super().__init__()
        # 可训练参数 theta ∈ R^D
        self.theta = nn.Parameter(torch.zeros(D))

    def forward(self, X):
        # softplus 保证正性
        w = F.softplus(self.theta)
        return X @ w

    def positive_params_vector(self):
        # 把当前的 “正锥参数” 摊平成一个向量，用于算 Hilbert 距离
        w = F.softplus(self.theta)
        return w.detach().clone()

# %%
def run_experiment_on_subset(
    X_full, y_full, n,
    num_epochs=500,
    lr=1e-2,
    l2_reg=1e-3,
    device="cuda"
):
    N, D = X_full.shape
    idx = torch.randperm(N, device=device)[:n]
    X = X_full[idx]
    y = y_full[idx]

    dataset = TensorDataset(X, y)
    loader = DataLoader(dataset, batch_size=n, shuffle=False)  # full-batch

    model = PositiveLinear(D).to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=lr)

    param_traj = []
    loss_traj = []

    for epoch in range(num_epochs):
        for batch_X, batch_y in loader:
            optimizer.zero_grad()

            # 1. 预测
            y_pred = model(batch_X)

            # 2. MSE 部分
            mse = F.mse_loss(y_pred, batch_y)

            # 3. L2 正则：在正锥中对 w = softplus(theta) 做正则
            w = F.softplus(model.theta)
            l2 = (w ** 2).sum()

            # 4. 总 loss = mse + λ ||w||^2
            loss = mse + l2_reg * l2

            loss.backward()
            optimizer.step()

        loss_traj.append(loss.item())
        param_traj.append(model.positive_params_vector().cpu())

    w_star = param_traj[-1]
    w_init = param_traj[0]

    hilbert_to_final = []
    hilbert_to_init = []
    hilbert_between = []

    prev = param_traj[0]
    for w_t in param_traj:
        hilbert_to_final.append(hilbert_distance(w_t, w_star))
        hilbert_to_init.append(hilbert_distance(w_t, w_init))
        hilbert_between.append(hilbert_distance(w_t, prev))
        prev = w_t

    return {
        "n": n,
        "loss_traj": loss_traj,
        "hilbert_to_final": hilbert_to_final,
        "hilbert_to_init": hilbert_to_init,
        "hilbert_between": hilbert_between,
        "w_star": w_star,
    }

# %%
def main():
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print("Using device:", device)

    # ----- 生成大样本 Swiss roll -----
    N = 10_000
    D = 32
    X_full, y_full, u, v = generate_swiss_roll(
        n_samples=N,
        D=D,
        noise=0.0,
        device=device,
    )
    print(f"Full dataset: X={X_full.shape}, y={y_full.shape}")

    # ----- 不同小样本规模 -----
    n_list = [50, 100, 200, 500]
    num_epochs = 500
    lr = 1e-2
    l2_list = [0.0, 1e-4, 1e-3, 1e-2]

    # all_results[n][l2_reg] = 对应的实验结果
    all_results = {}

    for n in n_list:
        all_results[n] = {}
        print(f"\n================ n = {n} ================")

        for l2_reg in l2_list:
            print(f"\n--- Running experiment (n={n}, l2_reg={l2_reg}) ---")
            res = run_experiment_on_subset(
                X_full,
                y_full,
                n=n,
                num_epochs=num_epochs,
                lr=lr,
                l2_reg=l2_reg,
                device=device,
            )
            all_results[n][l2_reg] = res

            print(f"Final loss: {res['loss_traj'][-1]:.6f}")
            print(f"Initial d_H(w_t, w*): {res['hilbert_to_final'][0]:.6f}")
            print(f"Final   d_H(w_t, w*): {res['hilbert_to_final'][-1]:.6f}")

            print("First 5 d_H(w_t, w*):", res["hilbert_to_final"][:5])
            print("First 5 d_H(w_t, w_0):", res["hilbert_to_init"][:5])
            print("First 5 d_H(w_{t+1}, w_t):", res["hilbert_between"][:5])

    # 例如保存结果
    torch.save(all_results, "swiss_roll_cone_l2_experiments.pt")

# %%
main()  # --- IGNORE ---
# Out:
# Using device: cuda
# Full dataset: X=torch.Size([10000, 32]), y=torch.Size([10000])
#
# ================ n = 50 ================
#
# --- Running experiment (n=50, l2_reg=0.0) ---
# Final loss: 0.000433
# Initial d_H(w_t, w*): 0.522001
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [0.5220013856887817, 0.28093230724334717, 0.15738874673843384, 0.0892389714717865, 0.0507592111825943]
# First 5 d_H(w_t, w_0): [0.0, 0.24106910824775696, 0.3647611439228058, 0.4329516589641571, 0.47135457396507263]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.24106910824775696, 0.12369201332330704, 0.06819042563438416, 0.038479648530483246]
#
# --- Running experiment (n=50, l2_reg=0.0001) ---
# Final loss: 0.002069
# Initial d_H(w_t, w*): 0.337782
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [0.3377816677093506, 0.1636822521686554, 0.08344727009534836, 0.04247519373893738, 0.021714933216571808]
# First 5 d_H(w_t, w_0): [0.0, 0.19020266830921173, 0.26559025049209595, 0.30133622884750366, 0.31923168897628784]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.19020266830921173, 0.08023495227098465, 0.04097210615873337, 0.020760204643011093]
#
# --- Running experiment (n=50, l2_reg=0.001) ---
# Final loss: 0.015529
# Initial d_H(w_t, w*): 0.444105
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [0.444105327129364, 0.21178480982780457, 0.11295784264802933, 0.06107985973358154, 0.03344946354627609]
# First 5 d_H(w_t, w_0): [0.0, 0.2337237298488617, 0.33182549476623535, 0.38346731662750244, 0.41088348627090454]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.2337237298488617, 0.0988270491361618, 0.051877960562705994, 0.02763032354414463]
#
# --- Running experiment (n=50, l2_reg=0.01) ---
# Final loss: 0.147202
# Initial d_H(w_t, w*): 0.586087
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [0.5860865712165833, 0.27221405506134033, 0.13788741827011108, 0.07616360485553741, 0.042916394770145416]
# First 5 d_H(w_t, w_0): [0.0, 0.31387245655059814, 0.4514038562774658, 0.5159794092178345, 0.5481818914413452]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.31387245655059814, 0.1375313401222229, 0.06457550823688507, 0.03324735909700394]
#
# ================ n = 100 ================
#
# --- Running experiment (n=100, l2_reg=0.0) ---
# Final loss: 0.000302
# Initial d_H(w_t, w*): 0.440592
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [0.44059211015701294, 0.19654661417007446, 0.1036149337887764, 0.055047325789928436, 0.02973800152540207]
# First 5 d_H(w_t, w_0): [0.0, 0.24520552158355713, 0.3374177813529968, 0.38596364855766296, 0.41112738847732544]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.24520552158355713, 0.0929315835237503, 0.04856767877936363, 0.025309307500720024]
#
# --- Running experiment (n=100, l2_reg=0.0001) ---
# Final loss: 0.001975
# Initial d_H(w_t, w*): 0.468206
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [0.46820616722106934, 0.24275624752044678, 0.13791358470916748, 0.07815716415643692, 0.04469472914934158]
# First 5 d_H(w_t, w_0): [0.0, 0.22544986009597778, 0.33029264211654663, 0.3900490403175354, 0.42351147532463074]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.22544986009597778, 0.10484279692173004, 0.0597563199698925, 0.033462390303611755]
#
# --- Running experiment (n=100, l2_reg=0.001) ---
# Final loss: 0.015145
# Initial d_H(w_t, w*): 0.496179
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [0.49617859721183777, 0.26976388692855835, 0.15929117798805237, 0.09585744142532349, 0.05889330059289932]
# First 5 d_H(w_t, w_0): [0.0, 0.2766111195087433, 0.3368873596191406, 0.4003211259841919, 0.4372852146625519]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.2766111195087433, 0.12105900794267654, 0.06343366205692291, 0.03696415573358536]
#
# --- Running experiment (n=100, l2_reg=0.01) ---
# Final loss: 0.142343
# Initial d_H(w_t, w*): 0.233154
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [0.23315365612506866, 0.11889222264289856, 0.06264594197273254, 0.03325051814317703, 0.017760511487722397]
# First 5 d_H(w_t, w_0): [0.0, 0.11426131427288055, 0.17050768435001373, 0.199903205037117, 0.21539315581321716]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.11426131427288055, 0.056246280670166016, 0.02939554490149021, 0.015489960089325905]
#
# ================ n = 200 ================
#
# --- Running experiment (n=200, l2_reg=0.0) ---
# Final loss: 0.000467
# Initial d_H(w_t, w*): 0.349873
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [0.34987273812294006, 0.1775699257850647, 0.09323340654373169, 0.04974149912595749, 0.02678227797150612]
# First 5 d_H(w_t, w_0): [0.0, 0.17230285704135895, 0.25663936138153076, 0.3001313805580139, 0.32310718297958374]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.17230285704135895, 0.08433650434017181, 0.043491918593645096, 0.022975891828536987]
#
# --- Running experiment (n=200, l2_reg=0.0001) ---
# Final loss: 0.001889
# Initial d_H(w_t, w*): 0.333534
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [0.33353421092033386, 0.16006696224212646, 0.08143050968647003, 0.041641298681497574, 0.021425331011414528]
# First 5 d_H(w_t, w_0): [0.0, 0.17346730828285217, 0.25210362672805786, 0.2918929159641266, 0.3121088743209839]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.17346730828285217, 0.07863648235797882, 0.03978923708200455, 0.02021609991788864]
#
# --- Running experiment (n=200, l2_reg=0.001) ---
# Final loss: 0.015576
# Initial d_H(w_t, w*): 0.327646
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [0.3276463747024536, 0.15327872335910797, 0.07489051669836044, 0.036862652748823166, 0.01825541816651821]
# First 5 d_H(w_t, w_0): [0.0, 0.18557360768318176, 0.26025235652923584, 0.29496729373931885, 0.3116663694381714]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.18557360768318176, 0.07838813960552216, 0.03802773728966713, 0.01860729604959488]
#
# --- Running experiment (n=200, l2_reg=0.01) ---
# Final loss: 0.145141
# Initial d_H(w_t, w*): 0.320087
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [0.3200867176055908, 0.15734612941741943, 0.07744503766298294, 0.03869517147541046, 0.01958315074443817]
# First 5 d_H(w_t, w_0): [0.0, 0.1762503981590271, 0.24268122017383575, 0.28157317638397217, 0.30079469084739685]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.1762503981590271, 0.07994053512811661, 0.038892000913619995, 0.019221549853682518]
#
# ================ n = 500 ================
#
# --- Running experiment (n=500, l2_reg=0.0) ---
# Final loss: 0.000431
# Initial d_H(w_t, w*): 0.295528
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [0.29552793502807617, 0.1403113156557083, 0.06888353079557419, 0.03398144990205765, 0.016827717423439026]
# First 5 d_H(w_t, w_0): [0.0, 0.16085192561149597, 0.23143336176872253, 0.26452839374542236, 0.2803955674171448]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.16085192561149597, 0.07142763584852219, 0.03490208834409714, 0.017153780907392502]
#
# --- Running experiment (n=500, l2_reg=0.0001) ---
# Final loss: 0.001897
# Initial d_H(w_t, w*): 0.245932
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [0.24593159556388855, 0.11189835518598557, 0.052530594170093536, 0.02498755231499672, 0.011967230588197708]
# First 5 d_H(w_t, w_0): [0.0, 0.134033203125, 0.1934010237455368, 0.2209440916776657, 0.23396438360214233]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.134033203125, 0.05936776101589203, 0.027542997151613235, 0.013020290993154049]
#
# --- Running experiment (n=500, l2_reg=0.001) ---
# Final loss: 0.015486
# Initial d_H(w_t, w*): 0.299675
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [0.2996748685836792, 0.14717277884483337, 0.07217679917812347, 0.035750843584537506, 0.017825907096266747]
# First 5 d_H(w_t, w_0): [0.0, 0.1527189016342163, 0.22749805450439453, 0.2639240622520447, 0.2818489968776703]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.1527189016342163, 0.07499592006206512, 0.03642592579126358, 0.01792490854859352]
#
# --- Running experiment (n=500, l2_reg=0.01) ---
# Final loss: 0.144261
# Initial d_H(w_t, w*): 0.313204
# Final   d_H(w_t, w*): 0.000000
# First 5 d_H(w_t, w*): [0.313204288482666, 0.1516248881816864, 0.07497872412204742, 0.03759200870990753, 0.01903615891933441]
# First 5 d_H(w_t, w_0): [0.0, 0.16157947480678558, 0.23822550475597382, 0.27561232447624207, 0.2941682040691376]
# First 5 d_H(w_{t+1}, w_t): [0.0, 0.16157947480678558, 0.07664613425731659, 0.03738679736852646, 0.018555955961346626]
